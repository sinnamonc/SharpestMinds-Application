# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from data_preprocessing import get_data_sets
import matplotlib.pyplot as plt
print('Complete')
# Out:
# Complete

# %%
test_data, test_labels, valid_data, valid_labels, train_data, train_labels = get_data_sets()
print('Complete')
# Out:
# Complete

# %%
for i in np.arange(0,10):
    plt.plot(test_data[:,i],'r*')
    plt.ylabel('feature')
    plt.xlabel('index')
#     plt.legend([i], loc='upper right')
    plt.show()

# %%
for i in np.arange(0,10):
    plt.hist(test_data[:,i],10)
    plt.ylabel('feature')
    plt.xlabel('index')
#     plt.legend([i], loc='upper right')
    plt.show()

# %%
PCA1 = PCA(n_components=20)
PCA1.fit(train_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-75a89c0cfd1b> in <module>()
# ----> 1 PCA1 = PCA(n_components=20)
#       2 PCA1.fit(train_data)
#
# TypeError: 'NoneType' object is not callable

# %%
PCA.explained_variance_ratio_
# Out:
# array([ 0.29991195,  0.08404414,  0.06860704,  0.06260049,  0.04949249,
#         0.04753935,  0.04087512,  0.03440373,  0.03015215,  0.02820791])
